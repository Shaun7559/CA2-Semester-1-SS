# %% [markdown]
# # Web scraper

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np

# %%
# Creating the web driver that will scrape the websites

driver = webdriver.Chrome(r"C:\Users\shaun\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/2026946682.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\shaun\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Irish farmers Association
# Here I add the IFA URL as a query along with keywords and ask
# the driver to get the query, I have also added a variable to search by css
# type amd finally one to search for links.

keywords = ["beef", "cattle", "mutton", "sheep", "prices", "price", "poultry",
            "CAP", "common agriculutral policy", "pig", "pork", "meat"]

for word in keywords:
    urlQuery = f"https://www.ifa.ie/?s={word}"
    driver.get(urlQuery)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_3884/825502804.py:12: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")

# %% [markdown]
# # Test file

# %%
# This scraper uses Selenium with a chrome driver to search the IFA website
# HTML element class names, it then loops through a set maximum number of pages
# amd returns any result contained within the keywords list

TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef"]

maxobservations = 1
sentimentdata = pd.DataFrame(columns=['Link', 'Date', 'Title', 'Text'])

for word in keywords:
    for i in range(maxobservations):
        SearchUrl = TargetUrl + str(i+1) + '/?s=' + word
        driver.get(SearchUrl)
        elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
        links = [elem.get_attribute('href') for elem in elems]
        for link in links:
            driver.get(link)
            try:
                page = driver.find_element_by_xpath("/html/body")
                sentimentdata = sentimentdata.append({'Link': link,
                                           'Date': page.find_element(By.CLASS_NAME, 'entry-date').text,
                                           'Title': page.find_element(By.CLASS_NAME, 'entry-title').text,
                                           'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                                          ignore_index=True)
            except:
                print('The crawler was unable to collect information on {}'.format(link))
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/1459275450.py:15: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/1459275450.py:20: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   page = driver.find_element_by_xpath("/html/body")
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-13th-may/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-6th-may/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-29th-april/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/immediate-funding-needed-to-safeguard-suckler-beef-sector/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-22nd-april/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/focus-of-beef-farmers-remains-on-sustainability/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/suckler-and-beef-farmers-must-be-supported-at-critical-time-for-sector/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-25th-march/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/measures-needed-to-avoid-disruption-on-beef-and-suckler-farms/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-11th-march/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/support-needed-to-maintain-confidence-among-beef-farmers/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/beef-sheep-update-25th-february/

# %%
# This scraper uses Selenium with a chrome driver to search the IFA website
# HTML element class names, it then loops through a set maximum number of pages
# amd returns any result contained within the keywords list

TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef"]

maxobservations = 1
sentimentdata = pd.DataFrame(columns=['Link', 'Date', 'Title', 'Text'])

for i in range(maxobservations):
    SearchUrl = TargetUrl + str(i+1) + '/?s=' + "beef"
    driver.get(SearchUrl)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
    for link in links:
        driver.get(link)
        try:
            page = driver.find_element_by_xpath("/html/body")
            sentimentdata = sentimentdata.append({'Link': link,
                                       'Date': page.find_element(By.CLASS_NAME, 'entry-date').text,
                                       'Title': page.find_element(By.CLASS_NAME, 'entry-title').text,
                                       'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                                      ignore_index=True)
        except:
            pass
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/2619515175.py:14: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/2619515175.py:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   page = driver.find_element_by_xpath("/html/body")

# %%
#Save to CSV
sentimentdata.to_csv("C:\\Users\\shaun\\Desktop\\IFA_sentiment_data.csv")

# %%
# This scraper uses Selenium with a chrome driver to search the IFA website
# HTML element class names, it then loops through a set maximum number of pages
# amd returns any result contained within the keywords list

TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef"]

maxobservations = 1
sentimentdata = pd.DataFrame(columns=['Link', 'Date', 'Title', 'Text'])

for i in range(maxobservations):
    SearchUrl = TargetUrl + str(i+1) + '/?s=' + "beef"
    driver.get(SearchUrl)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
    for link in links:
        driver.get(link)
        page = driver.find_element_by_xpath("/html/body")
        sentimentdata = sentimentdata.append({'Link': link,
                                   'Date': page.find_element(By.CLASS_NAME, 'entry-date').text,
                                   'Title': page.find_element(By.CLASS_NAME, 'entry-title').text,
                                   'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                                      ignore_index=True)
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/754503427.py:14: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
# C:\Users\shaun\AppData\Local\Temp/ipykernel_5440/754503427.py:18: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   page = driver.find_element_by_xpath("/html/body")

# %%
sentimentdata.to_csv("C:\\Users\\shaun\\Desktop\\ffs.csv")

# %% [markdown]
# # Davids

# %%
searchUrl = 'https://www.ifa.ie/page/'
searchTerms = 'beef+cattle+prices'

maxPages = 1
allPages = pd.DataFrame(columns=['Link', 'Date', 'Title', 'Text'])

for i in range(maxPages):
    currentUrl = searchUrl + str(i+1) + '/?s=' + searchTerms
    driver.get(currentUrl)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
    for link in links:
        driver.get(link)
        try:
            page = driver.find_elements_by_xpath("/html/body")
            allPages = allPages.append({'Link': link,
                                       'Date': page.find_element(By.CLASS_NAME, 'entry-date').text,
                                       'Title': page.find_element(By.CLASS_NAME, 'entry-title').text,
                                       'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                                      ignore_index=True)
        except:
            print("Test failed{}".format(link))
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_3884/1333472358.py:10: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
# C:\Users\shaun\AppData\Local\Temp/ipykernel_3884/1333472358.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   page = driver.find_elements_by_xpath("/html/body")
# Test failedhttps://www.ifa.ie/markets-and-prices/strong-beef-market-demand-should-be-reflected-in-higher-cattle-prices/
# Test failedhttps://www.ifa.ie/markets-and-prices/tighter-cattle-supplies-brings-more-bite-to-beef-trade-as-uk-prices-continue-to-rise-ifa/
# Test failedhttps://www.ifa.ie/markets-and-prices/beef-farmers-digging-in-hard-on-cattle-prices-ifa/
# Test failedhttps://www.ifa.ie/markets-and-prices/beef-finishers-determined-to-dig-in-on-cattle-prices-ifa/
# Test failedhttps://www.ifa.ie/markets-and-prices/uk-beef-price-rise-must-lift-irish-cattle-prices-ifa/
# Test failedhttps://www.ifa.ie/markets-and-prices/news-article-5208/
# Test failedhttps://www.ifa.ie/markets-and-prices/beef-sheep-update-13th-may/
# Test failedhttps://www.ifa.ie/farm-sectors/suckler-and-cattle-farmers-most-exposed-by-inputs-increases/
# Test failedhttps://www.ifa.ie/markets-and-prices/beef-sheep-update/
# Test failedhttps://www.ifa.ie/farm-sectors/focus-of-beef-farmers-remains-on-sustainability/
# Test failedhttps://www.ifa.ie/farm-sectors/suckler-and-beef-farmers-must-be-supported-at-critical-time-for-sector/
# Test failedhttps://www.ifa.ie/markets-and-prices/beef-sheep-update-25th-march/
# Test failedhttps://www.ifa.ie/farm-sectors/measures-needed-to-avoid-disruption-on-beef-and-suckler-farms/

# %%
#Save to CSV
sentimentdata.to_csv("C:\\Users\\shaun\\Desktop\\Test.csv")

# %% [markdown]
# # Working do not delete

# %%
# This scraper uses Selenium with a chrome driver to search the IFA website
# HTML element class names, it then loops through a set maximum number of pages
# amd returns any result contained within the keywords list

TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef", "cattle", "mutton", "sheep", "prices", "price", "poultry",
            "CAP", "common agriculutral policy", "pig", "pork", "meat"]

maxobservations = 100
sentimentdata = pd.DataFrame(columns=['Link', 'Date', 'Title', 'Text'])

for word in keywords:
    for i in range(maxobservations):
        SearchUrl = TargetUrl + str(i+1) + '/?s=' + word
        driver.get(SearchUrl)
        elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
        links = [elem.get_attribute('href') for elem in elems]
        for link in links:
            driver.get(link)
            try:
                page = driver.find_element_by_xpath("/html/body")

# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-11th-march/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-26th-february/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/cattle-factory-prices-19th-february/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/cattle-factory-prices-12th-february/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/cattle-finishers-demand-more-on-beef-ifa/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-29th-january/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/cattle-factory-prices-22nd-january/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/cattle-factory-prices-16th-january/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/cattle-factory-prices-15th-january/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-9th-january/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/cattle-prices-must-rise/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-11th-december-2/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-11th-december/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/factory-cattle-prices-20th-november/
# The crawler was unable to collect information on https://www.ifa.ie/markets-and-prices/cattle-factory-prices-13th-november/
# The crawler was unable to collect information on https://www.ifa.ie/farm-sectors/cattle-price-rise-justified-based-on-rising-market-returns/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3884/2289504164.py in <module>
#      17         links = [elem.get_attribute('href') for elem in elems]
#      18         for link in links:
# ---> 19             driver.get(link)
#      20             try:
#      21                 page = driver.find_element_by_xpath("/html/body")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     440         Loads a web page in the current browser session.
#     441         """
# --> 442         self.execute(Command.GET, {'url': url})
#     443
#     444     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426
#     427         params = self._wrap_value(params)
# --> 428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
#     430             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     345         data = utils.dump_json(params)
#     346         url = f"{self._url}{path}"
# --> 347         return self._request(command_info[0], url, body=data)
#     348
#     349     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     367
#     368         if self.keep_alive:
# --> 369             response = self._conn.request(method, url, body=body, headers=headers)
#     370             statuscode = response.status
#     371         else:
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Save to CSV
sentimentdata.to_csv("C:\\Users\\shaun\\Desktop\\IFA_sentiment_data.csv")

# %% [markdown]
# # Old work

# %%
# This scraper uses Selenium with a chrome driver to search the IFA website
# HTML element class names, it then loops through a set maximum number of pages
# amd returns any result contained within the keywords list

TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef", "cattle", "mutton", "sheep", "prices", "price", "poultry",
            "CAP", "common agriculutral policy", "pig", "pork", "meat"]

maxobservations = 100
sentimentdata = pd.DataFrame(columns=['Link', 'Date', 'Title', 'Text'])

for i in range(maxobservations):
    SearchUrl = TargetUrl + str(i+1) + '/?s=' + word in keywords
    driver.get(SearchUrl)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
    for link in links:
        driver.get(link)
        try:
            page = driver.find_element_by_xpath("/html/body")
            sentimentdata = sentimentdata.append({'Link': link,
                                       'Date': page.find_element(By.CLASS_NAME, 'entry-date').text,
                                       'Title': page.find_element(By.CLASS_NAME, 'entry-title').text,
                                       'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                                      ignore_index=True)
        except:
            print('The crawler was unable to collect information on {}'.format(link))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3884/2115980531.py in <module>
#      12 for i in range(maxobservations):
#      13     SearchUrl = TargetUrl + str(i+1) + '/?s=' + word in keywords
# ---> 14     driver.get(SearchUrl)
#      15     elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
#      16     links = [elem.get_attribute('href') for elem in elems]
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     440         Loads a web page in the current browser session.
#     441         """
# --> 442         self.execute(Command.GET, {'url': url})
#     443
#     444     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# InvalidArgumentException: Message: invalid argument: 'url' must be a string
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0043B8F3+2406643]
# 	Ordinal0 [0x003CAF31+1945393]
# 	Ordinal0 [0x002BC748+837448]
# 	Ordinal0 [0x00314E06+1199622]
# 	Ordinal0 [0x0030427C+1131132]
# 	Ordinal0 [0x00314682+1197698]
# 	Ordinal0 [0x00304096+1130646]
# 	Ordinal0 [0x002DE636+976438]
# 	Ordinal0 [0x002DF546+980294]
# 	GetHandleVerifier [0x006A9612+2498066]
# 	GetHandleVerifier [0x0069C920+2445600]
# 	GetHandleVerifier [0x004D4F2A+579370]
# 	GetHandleVerifier [0x004D3D36+574774]
# 	Ordinal0 [0x003D1C0B+1973259]
# 	Ordinal0 [0x003D6688+1992328]
# 	Ordinal0 [0x003D6775+1992565]
# 	Ordinal0 [0x003DF8D1+2029777]
# 	BaseThreadInitThunk [0x75D86739+25]
# 	RtlGetFullPathName_UEx [0x772F8FEF+1215]
# 	RtlGetFullPathName_UEx [0x772F8FBD+1165]

# %%
TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef", "cattle", "mutton", "sheep", "prices", "price", "poultry",
            "CAP", "common agriculutral policy", "pig", "pork", "meat"]

maxobservations = 50
sentimentdata = pd.Dataframe(columns=['Link', 'Date', 'Title', 'Text'])

for i in range(maxpages):
    SearchUrl = TargetUrl + str(i+1) + '/?s=' + keywords
    driver.get(currentUrl)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
    for link in links:
        driver.get(link)
        try
        page = driver.find_element_by_xpath("/html/body")
    driver.find_elements_by_xpath("/html/body")
    sentimentdata = sentimentdata.append({'Link': link,
                               'Date': page.find_element(By.CLASS_NAME, 'entry-date').text
                               'Title': page.find_element(By.CLASS_NAME, 'entry-title').text
                               'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                              ignore_index=True)
    except:
        print('The crawler was unable to collect information on {}'.format(link))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3884/825502804.py in <module>
#       9 for word in keywords:
#      10     urlQuery = f"https://www.ifa.ie/?s={word}"
# ---> 11     driver.get(urlQuery)
#      12     elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
#      13     links = [elem.get_attribute('href') for elem in elems]
#
# NameError: name 'driver' is not defined

# %%
for link in links:
    print(link)
# Out:
# https://www.ifa.ie/campaigns/ifa-contacts-key-international-public-health-agencies-on-red-meat-data/
# https://www.ifa.ie/campaigns/scientists-raise-serious-questions-about-reliability-of-data-on-impact-of-red-meat/
# https://www.ifa.ie/farm-sectors/ifa-welcomes-bord-bia-promotional-campaign-for-pig-meat/
# https://www.ifa.ie/farm-sectors/pig-farmers-expect-retailers-to-use-bord-bia-qa-pigmeat/
# https://www.ifa.ie/campaigns/support-and-buy-irish-bord-bia-quality-assured-pigmeat-not-imports/
# https://www.ifa.ie/farm-sectors/procedures-around-imports-of-sheep-meat-must-be-strong-and-robust/
# https://www.ifa.ie/policy-areas/positive-market-outlook-for-sheep-meat/
# https://www.ifa.ie/farm-sectors/cutting-promotion-of-meat-products-would-be-a-rash-decision/
# https://www.ifa.ie/farm-sectors/european-parliament-can-block-attempt-by-plant-based-products-to-ride-on-coattails-of-meat/
# https://www.ifa.ie/farm-sectors/onus-on-meat-factories-to-act-responsibly/
# https://www.ifa.ie/farm-sectors/ifa-hand-in-letters-of-protest-to-meat-industry-ireland-and-minister-creed-over-beef-price-and-breaches-of-the-beef-sector-agreement/
# https://www.ifa.ie/policy-areas/sustainability-brief-meat-and-dairy-in-a-balanced-diet/
# https://www.ifa.ie/farm-sectors/jail-threat-by-meat-plants-will-be-fully-resisted-by-ifa-healy/

# %%
for elem in elems:
    print(elem)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="de9a08b0-431f-467a-b017-029fecad3684")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="b44f659b-35c9-47ec-aa68-7c918630a39a")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="79d6505c-be02-4460-b6f1-2f493c8fac2b")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="37debc12-4509-4429-a121-ed107771c432")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="3bf66e01-a84d-4152-b7bc-c8f5f1546d66")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="230bdbd5-9753-4501-9e0f-7e42ee7090a9")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="a3d46f5c-8e83-45cb-9162-429552af50f6")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="45df10fd-da5e-4c46-9913-d71e450304a2")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="d8ffa454-7760-4e97-933a-94f6f50c26fc")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="ac7be04f-b382-4b06-a882-2126e2d2ea19")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="e96cf4aa-6213-4759-97df-5fa9273cecef")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="6204079f-e032-4477-875b-d5b4c426a842")>
# <selenium.webdriver.remote.webelement.WebElement (session="ce89566919a28a0ad645fe60670f62d7", element="18f6b9b7-5861-4e3e-88ee-a471838331ed")>

# %%
from selenium.webdriver.common.by import By

driver.get(links[0])
page = driver.find_element_by_xpath("/html/body")
print('URL Title: \n {} \n'.format(page.find_element(By.CLASS_NAME, 'entry-title').text))
print('URL Date: \n {} \n'.format(page.find_element(By.CLASS_NAME, 'entry-date').text))
print('URL Text: \n {}'.format(page.find_element(By.CLASS_NAME, 'single-content').text))
# Out:
# URL Title:
#  IFA Contacts Key International Public Health Agencies on Red Meat Data
#
# URL Date:
#  28 February 2022
#
# URL Text:
#  Following the publication of a letter from scientists questioning data on the health impacts of red meat, IFA President Tim Cullinan has written to the Editor in Chief of The Lancet; the Minister for Agriculture Charlie McConalogue; the EU Commission; the United Nations; and the WHO asking that the questions raised by the scientists be addressed.
# “These key policy-making agencies, which are responsible for public health guidelines, must address the scientific questions raised about a study which attempted to demonise red meat,” he said.
# “The data in question, from ‘Global Burden of Disease’ of 2019, has since been cited in 635 documents, 351 scientific papers and nine policy documents. The questions raised by the scientists in The Lancet must be addressed urgently by the original authors and policy makers,” he said.
# “The scientists have been fighting a long battle to have their concerns published by The Lancet. There must now be a response from the Global Burden of Disease to address the problem. If this is not forthcoming, then policy-making agencies must disregard the study and revisit any policies which were influenced by it,” he said.
# So far, it appears the original authors, the ‘Global Burden of Disease’ based in the US, have declined to properly address the scientific questions raised by the scientists, which include Prof. Alice Stanton and Prof. Patrick Wall from Ireland.
# C:\Users\Shaun\AppData\Local\Temp/ipykernel_4576/1199310602.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   page = driver.find_element_by_xpath("/html/body")

# %%
IFA = []

for url in urlQuery:
    driver.get(urlQuery)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]

# %%
TargetUrl = 'https://www.ifa.ie/page/'
keywords = ["beef", "cattle", "mutton", "sheep", "prices", "price", "poultry",
            "CAP", "common agriculutral policy", "pig", "pork", "meat"]

maxobservations = 50
sentimentdata = pd.Dataframe(columns=['Link', 'Date', 'Title', 'Text'])

for i in range(maxpages):
    SearchUrl = TargetUrl + str(i+1) + '/?s=' + keywords
    driver.get(currentUrl)
    elems = driver.find_elements_by_css_selector(".col-sm-12 [href]")
    links = [elem.get_attribute('href') for elem in elems]
    for link in links:
        driver.get(link)
        try
        page = driver.find_element_by_xpath("/html/body")
    driver.find_elements_by_xpath("/html/body")
    sentimentdata = sentimentdata.append({'Link': link,
                               'Date': page.find_element(By.CLASS_NAME, 'entry-date').text
                               'Title': page.find_element(By.CLASS_NAME, 'entry-title').text
                               'Text': page.find_element(By.CLASS_NAME, 'single-content').text},
                              ignore_index=True)
    except:
        print('The crawler was unable to collect information on {}'.format(link))

# %% [markdown]
# # The Appendix of nonsense

# %% [markdown]
# ## Old code keep

# %%
articles = driver.find_elements_by_class_name("modal-open")
len(articles)
# Out:
# C:\Users\Shaun\AppData\Local\Temp/ipykernel_2940/2722688744.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   articles = driver.find_elements_by_class_name("modal-open")
# 1

# %%
print(articles[0].text)
# Out:
# SIGN IN
# USE PAPER CODE
# SUBSCRIBE
# SEARCH
# BEEF DAIRY SHEEP AGRIBUSINESS MACHINERY TILLAGE PEDIGREE BUILDINGS PROPERTY KNOWLEDGE HUB IRISH COUNTRY LIVING
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3 free articles left this month.
#   Subscribe for just €1 to get unlimited access for 30 days.
# SUBSCRIBE
#
#
# Watch: UCD Ag Soc raffle closing this week
# This week is the last chance to enter UCD’s Agricultural Society Grand Raffle, raising funds for the Irish Community Air Ambulance and Hooves 4 Hospice charities.
# Niamh Gunn
# NEWS > NEWS
# 9 May 2022
# UCD AG Soc grand raffle 2022. Top prize is a Fordson Dexta. All proceeds go to Hooves4Hospice and Irish Community Air Ambulance.
# UCD’s Agricultural Science Society (Ag Soc) raffle is coming to an end, with the raffle set to close on Friday 13 May at Balmoral Show. The winners will be announced on Saturday 14 May.
# This year’s raffle has been supported by a wide variety of companies and organisations across the country, with a number of exceptional prizes up for grabs and over €20,000 worth of prizes to be won.
# There are a large number of prizes available, with first prize being ‘Dixie’ a fully restored Fordson Dexta vintage tractor, sponsored by FBD Insurance.
# Also included in the list of prizes is two tonnes of Terra CAN, pedigree Limousin and Fleckvieh heifers, a Grasshopper and much more.
# There is also a selection of non-agricultural prizes which include a Coppers Gold card, a Tipperary dry-aged Angus meat hamper worth €500 and a spa weekend getaway for two in Mount Wolseley Hotel.
# Charities
# The two worthy charities chosen by the society this year are Hooves 4 Hospice and the Irish Community Air Ambulance.
# Hooves 2 Hospice is a charity that has joined forces with the farming community and supportive organisations to raise a sizeable sum of money towards the costs of building the much-needed Midland Regional Hospice. They aim to recruit a large number of farmers who are willing to rear an animal, and donate the animal or the funds from the animal to the charity.
# The second charity selected is the Irish Community Air Ambulance, Ireland’s only dedicated, and charity funded air ambulance. The Irish Community Air Ambulance is an asset of the National Ambulance Service and responds to the most serious trauma and medical emergencies in rural Ireland. In their first 12 months of service, nearly 500 missions were carried out, with each mission costing €3,000.
# The UCD AgSoc has a long history of raising money for charities both on and off campus with their events throughout the year, such as an ag-week, an on campus teashop and much more.
# You can buy a ticket and donate through here.
# Angus
# Charity
# Events
# FBD
# Farmers
# Pedigree
# UCD
# Vintage
# MOST READ
#   Titanic sails away with €4,300 in Kilmallock
#   Dairy supply shortage to continue
#   Retail demand for beef eases
#   Big pressure on supply driving beef quotes
#   Sheep prices update: Lamb numbers rising steadily in mart sales
# RELATED STORIES
# Noel Bardon
# One-to-one farm tragedy support EIP launched by Embrace FARM
# The project has been funded by the Department under the EIP initiative.
# The Dealer
# Ag Soc's big raffle
# It's that time of year again when UCD Ag Soc run its annual grand raffle. There is over €20,000 worth of prizes up for grabs this year.
# Declan O'Brien
# Irish cattle population broken up into seven herd types
# The study offers benefits for disease control, calculating carbon emissions and undertaking profitability comparisons between the different enterprises.
# Barry Murphy
# Bord Bia launches 2023 marketing fellowship
# Bord Bia is seeking the next intake to its marketing fellowship, which it says will support the future leaders of Ireland’s food and drink sector.
#
#
#
# search
# SIGN IN
# USE PAPER CODE
# SUBSCRIBE
# NEWS
# Latest headlines
# Editorial
# Viewpoints
# Farmer Writes
# The Dealer
# Northern Ireland
# Scotland
# Live weather
# LIVESTOCK
# Beef
# Dairy
# Sheep
# Animal health
# Pedigree
# Pigs
# Poultry
# MORE
# Agribusiness
# Tillage
# Machinery
# Property
# Buildings
# Forestry
# Climate
# Farm safety
# Sponsored articles
# KNOWLEDGE HUB
# Specialist articles
# Tools & calculators
# Farm programmes
# eLearning
# SHOP
# Merchandise
# Magazines
# MULTIMEDIA
# Videos
# Podcasts
# Photography
# PARTNERS
# Traction Marketing
# Toplink.ie
# The Irish Field
# Irish Country Magazine
# COUNTRY LIVING
# Features
# Columns
# Food
# Health
# Gardening
# Careers
# The Irish Horse
# Contact us Advertise with us Company information Career opportunities Privacy statement Terms of service Commenting policy Change cookies settings
# © Irish Farmers Journal 2022

# %%
print(articles[-1].text)
# Out:
# SIGN IN
# USE PAPER CODE
# SUBSCRIBE
# SEARCH
# BEEF DAIRY SHEEP AGRIBUSINESS MACHINERY TILLAGE PEDIGREE BUILDINGS PROPERTY KNOWLEDGE HUB IRISH COUNTRY LIVING
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5 free articles left this month.
#   Subscribe for just €1 to get unlimited access for 30 days.
# SUBSCRIBE
#
#
# Making the final call on maiden heifers for breeding
# Replacement heifers should have a minimum target liveweight to meet before the breeding season starts. This improves conception rates and reduces issues at calving time.
# Kieran Mailey
# BEEF > MANAGEMENT
# 10 May 2022
# Replacement heifers should meet a minimum target weight before breeding starts.
# On suckler farms where cows calve during March and April, breeding usually gets under way towards the end of May.
# Therefore now is the time to make a final call on maiden heifers that will be mated this year. Breeding weight is crucial to get heifers cycling and holding to service.
# It is also a major factor in getting heifers fully developed, so they can cope with the demands of pregnancy, calving, producing milk and going back in-calf again next year.
# The heavier the better
# Heifers should weigh at least 60% of the average mature cow weight in the herd once breeding starts. But the heavier heifers are, the better.
# If mature cows are typically 750kg, then heifers should weigh at least 450kg now. Any lighter and the chances of calving difficulty and not going back in-calf increase.
# So over the next week, maiden heifers should be weighed to get an accurate handle on liveweight. Heifers below the target breeding weight should be removed from the group.
# However, heifers that exhibit more extreme muscling in the hindquarters should be avoided, regardless if they meet target breeding weights.
# These animals are also more likely to encounter greater problems at calving time next year, even when bred to easy calving sires.
# READ MORE
# Sheep prices update: Lamb numbers rising steadily in mart sales
# Big pressure on supply driving beef quotes
# Breeding
# Calving
# Cattle weighing
# Cows
# Heifers
# Liveweight
# Replacement heifers
# Selecting replacements
# Weighing cattle
# RELATED STORIES
# Advertiser Announcement
# Improving profitability through excellent reproductive performance
# Compact calving and six-week calving rate is crucial for profitability on your farm.
# Aidan Brennan
# Dairy Management: how to avoid yo-yo farming
# Farmers must walk the farm every five or six days at this time of year to help make more informed decisions around grass.
# Kieran Mailey
# Five options to group suckler cows for breeding
# The breeding season for many suckler calving herds will be getting under way during May. Outlined are five options to group cows for breeding.
# Aidan Brennan
# Protocols for synching cows and heifers
# Aidan Brennan outlines some of the protocols for synchronising heats in cows and heifers.
#
#
#
# search
# SIGN IN
# USE PAPER CODE
# SUBSCRIBE
# NEWS
# Latest headlines
# Editorial
# Viewpoints
# Farmer Writes
# The Dealer
# Northern Ireland
# Scotland
# Live weather
# LIVESTOCK
# Beef
# Dairy
# Sheep
# Animal health
# Pedigree
# Pigs
# Poultry
# MORE
# Agribusiness
# Tillage
# Machinery
# Property
# Buildings
# Forestry
# Climate
# Farm safety
# Sponsored articles
# KNOWLEDGE HUB
# Specialist articles
# Tools & calculators
# Farm programmes
# eLearning
# SHOP
# Merchandise
# Magazines
# MULTIMEDIA
# Videos
# Podcasts
# Photography
# PARTNERS
# Traction Marketing
# Toplink.ie
# The Irish Field
# Irish Country Magazine
# COUNTRY LIVING
# Features
# Columns
# Food
# Health
# Gardening
# Careers
# The Irish Horse
# Contact us Advertise with us Company information Career opportunities Privacy statement Terms of service Commenting policy Change cookies settings
# © Irish Farmers Journal 2022

# %% [markdown]
# ## For tomorrow

# %% [markdown]
# Urls:
#
# https://medium.com/ml-book/web-scraping-using-selenium-python-3be7b8762747
#
# https://selenium-python.readthedocs.io/index.html
#
# https://newbedev.com/python-selenium-get-href-value
#
# https://www.farmersjournal.ie/making-the-final-call-on-maiden-heifers-for-breeding-696038

# %%
articles2 = driver.find_elements_by_class_name("sid-plesk")
len(articles2)
# Out:
# C:\Users\Shaun\AppData\Local\Temp/ipykernel_2940/3727337053.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   articles2 = driver.find_elements_by_class_name("sid-plesk")
# 1

# %%
print(articles2[0].text)
# Out:
# SIGN IN
# USE PAPER CODE
# SUBSCRIBE
# SEARCH
# BEEF DAIRY SHEEP AGRIBUSINESS MACHINERY TILLAGE PEDIGREE BUILDINGS PROPERTY KNOWLEDGE HUB IRISH COUNTRY LIVING
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3 free articles left this month.
#   Subscribe for just €1 to get unlimited access for 30 days.
# SUBSCRIBE
#
#
# Watch: UCD Ag Soc raffle closing this week
# This week is the last chance to enter UCD’s Agricultural Society Grand Raffle, raising funds for the Irish Community Air Ambulance and Hooves 4 Hospice charities.
# Niamh Gunn
# NEWS > NEWS
# 9 May 2022
# UCD AG Soc grand raffle 2022. Top prize is a Fordson Dexta. All proceeds go to Hooves4Hospice and Irish Community Air Ambulance.
# UCD’s Agricultural Science Society (Ag Soc) raffle is coming to an end, with the raffle set to close on Friday 13 May at Balmoral Show. The winners will be announced on Saturday 14 May.
# This year’s raffle has been supported by a wide variety of companies and organisations across the country, with a number of exceptional prizes up for grabs and over €20,000 worth of prizes to be won.
# There are a large number of prizes available, with first prize being ‘Dixie’ a fully restored Fordson Dexta vintage tractor, sponsored by FBD Insurance.
# Also included in the list of prizes is two tonnes of Terra CAN, pedigree Limousin and Fleckvieh heifers, a Grasshopper and much more.
# There is also a selection of non-agricultural prizes which include a Coppers Gold card, a Tipperary dry-aged Angus meat hamper worth €500 and a spa weekend getaway for two in Mount Wolseley Hotel.
# Charities
# The two worthy charities chosen by the society this year are Hooves 4 Hospice and the Irish Community Air Ambulance.
# Hooves 2 Hospice is a charity that has joined forces with the farming community and supportive organisations to raise a sizeable sum of money towards the costs of building the much-needed Midland Regional Hospice. They aim to recruit a large number of farmers who are willing to rear an animal, and donate the animal or the funds from the animal to the charity.
# The second charity selected is the Irish Community Air Ambulance, Ireland’s only dedicated, and charity funded air ambulance. The Irish Community Air Ambulance is an asset of the National Ambulance Service and responds to the most serious trauma and medical emergencies in rural Ireland. In their first 12 months of service, nearly 500 missions were carried out, with each mission costing €3,000.
# The UCD AgSoc has a long history of raising money for charities both on and off campus with their events throughout the year, such as an ag-week, an on campus teashop and much more.
# You can buy a ticket and donate through here.
# Angus
# Charity
# Events
# FBD
# Farmers
# Pedigree
# UCD
# Vintage
# MOST READ
#   Titanic sails away with €4,300 in Kilmallock
#   Dairy supply shortage to continue
#   Retail demand for beef eases
#   Big pressure on supply driving beef quotes
#   Sheep prices update: Lamb numbers rising steadily in mart sales
# RELATED STORIES
# Noel Bardon
# One-to-one farm tragedy support EIP launched by Embrace FARM
# The project has been funded by the Department under the EIP initiative.
# The Dealer
# Ag Soc's big raffle
# It's that time of year again when UCD Ag Soc run its annual grand raffle. There is over €20,000 worth of prizes up for grabs this year.
# Declan O'Brien
# Irish cattle population broken up into seven herd types
# The study offers benefits for disease control, calculating carbon emissions and undertaking profitability comparisons between the different enterprises.
# Barry Murphy
# Bord Bia launches 2023 marketing fellowship
# Bord Bia is seeking the next intake to its marketing fellowship, which it says will support the future leaders of Ireland’s food and drink sector.
#
#
#
# search
# SIGN IN
# USE PAPER CODE
# SUBSCRIBE
# NEWS
# Latest headlines
# Editorial
# Viewpoints
# Farmer Writes
# The Dealer
# Northern Ireland
# Scotland
# Live weather
# LIVESTOCK
# Beef
# Dairy
# Sheep
# Animal health
# Pedigree
# Pigs
# Poultry
# MORE
# Agribusiness
# Tillage
# Machinery
# Property
# Buildings
# Forestry
# Climate
# Farm safety
# Sponsored articles
# KNOWLEDGE HUB
# Specialist articles
# Tools & calculators
# Farm programmes
# eLearning
# SHOP
# Merchandise
# Magazines
# MULTIMEDIA
# Videos
# Podcasts
# Photography
# PARTNERS
# Traction Marketing
# Toplink.ie
# The Irish Field
# Irish Country Magazine
# COUNTRY LIVING
# Features
# Columns
# Food
# Health
# Gardening
# Careers
# The Irish Horse
# Contact us Advertise with us Company information Career opportunities Privacy statement Terms of service Commenting policy Change cookies settings
# © Irish Farmers Journal 2022
